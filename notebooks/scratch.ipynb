# %% [markdown]
# # Scratch notebook
#
# A place to test simple code against the `simply` codebase.
# Run the setup cell first so `import simply...` works from anywhere.
#
# Kernel: **Python (simply)** (the project's `.venv`, JAX in CPU mode).

# %%
# Setup: make the repo root importable
import sys, os
REPO = os.path.abspath(os.path.join(os.getcwd(), os.pardir))
if REPO not in sys.path:
    sys.path.insert(0, REPO)
print('repo:', REPO)
print('python:', sys.executable)

# %%
# Quick env check
import jax
print('jax', jax.__version__, '| devices:', jax.devices())

# %%
# Auto-reload edited source files without restarting the kernel
# %load_ext autoreload
# %autoreload 2

# %%
# Example: build a tiny config from the registry
from simply import config_lib
print(type(config_lib))

# Your scratch code here
